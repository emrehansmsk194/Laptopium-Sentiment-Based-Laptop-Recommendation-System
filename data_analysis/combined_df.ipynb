# %%
import pandas as pd 
import numpy as np 

df = pd.read_csv("combined_products.csv")
df
# Out:
#                                                   Image  \
# 0     https://m.media-amazon.com/images/I/61wH5UlX-M...
# 1     https://m.media-amazon.com/images/I/51dHk31mrQ...
# 2     https://m.media-amazon.com/images/I/61DQ67Cr2H...
# 3     https://m.media-amazon.com/images/I/51zyo-VeNS...
# 4     https://m.media-amazon.com/images/I/514DRQG0T7...
# ...                                                 ...
# 1289  https://cdn.dsmcdn.com/ty1536/product/media/im...
# 1290  https://cdn.dsmcdn.com/ty1549/product/media/im...
# 1291  https://cdn.dsmcdn.com/ty1197/product/media/im...
# 1292  https://cdn.dsmcdn.com/ty1622/prod/QC/20250109...
# 1293  https://cdn.dsmcdn.com/ty839/product/media/ima...
#
#                                                    Link         Price  \
# 0     https://www.amazon.com.tr/Lenovo-Bilgisayar-i5...     15.499 TL
# 1     https://www.amazon.com.tr/ASUS-Vivobook-15-X15...     14.999 TL
# 2     https://www.amazon.com.tr/Lenovo-IdeaPad-Bilgi...     11.659 TL
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1294 entries, 0 to 1293
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Image         1294 non-null   object
#  1   Link          1294 non-null   object
#  2   Price         1290 non-null   object
#  3   Product Name  1294 non-null   object
#  4   Reviews       1195 non-null   object
# dtypes: object(5)
# memory usage: 50.7+ KB

# %%
new_df = df.copy()
new_df
# Out:
#                                                   Image  \
# 0     https://m.media-amazon.com/images/I/61wH5UlX-M...
# 1     https://m.media-amazon.com/images/I/51dHk31mrQ...
# 2     https://m.media-amazon.com/images/I/61DQ67Cr2H...
# 3     https://m.media-amazon.com/images/I/51zyo-VeNS...
# 4     https://m.media-amazon.com/images/I/514DRQG0T7...
# ...                                                 ...
# 1289  https://cdn.dsmcdn.com/ty1536/product/media/im...
# 1290  https://cdn.dsmcdn.com/ty1549/product/media/im...
# 1291  https://cdn.dsmcdn.com/ty1197/product/media/im...
# 1292  https://cdn.dsmcdn.com/ty1622/prod/QC/20250109...
# 1293  https://cdn.dsmcdn.com/ty839/product/media/ima...
#
#                                                    Link         Price  \
# 0     https://www.amazon.com.tr/Lenovo-Bilgisayar-i5...     15.499 TL
# 1     https://www.amazon.com.tr/ASUS-Vivobook-15-X15...     14.999 TL
# 2     https://www.amazon.com.tr/Lenovo-IdeaPad-Bilgi...     11.659 TL
# ...

# %%
def fix_price(price):
    # Eğer fiyat bir string ve ',' içeriyorsa
    if isinstance(price, str) and ',' in price:
        # Noktadan önceki kısmı al (binlik ayırıcıları kaldır)
        return price.split(',')[0] + ' TL'
    return price  # Eğer fiyat düzgünse dokunma

new_df['Price'] = new_df['Price'].apply(fix_price)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1294 entries, 0 to 1293
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Image         1294 non-null   object
#  1   Link          1294 non-null   object
#  2   Price         1290 non-null   object
#  3   Product Name  1294 non-null   object
#  4   Reviews       1195 non-null   object
# dtypes: object(5)
# memory usage: 50.7+ KB

# %%
new_df
# Out:
#                                                   Image  \
# 0     https://m.media-amazon.com/images/I/61wH5UlX-M...
# 1     https://m.media-amazon.com/images/I/51dHk31mrQ...
# 2     https://m.media-amazon.com/images/I/61DQ67Cr2H...
# 3     https://m.media-amazon.com/images/I/51zyo-VeNS...
# 4     https://m.media-amazon.com/images/I/514DRQG0T7...
# ...                                                 ...
# 1289  https://cdn.dsmcdn.com/ty1536/product/media/im...
# 1290  https://cdn.dsmcdn.com/ty1549/product/media/im...
# 1291  https://cdn.dsmcdn.com/ty1197/product/media/im...
# 1292  https://cdn.dsmcdn.com/ty1622/prod/QC/20250109...
# 1293  https://cdn.dsmcdn.com/ty839/product/media/ima...
#
#                                                    Link      Price  \
# 0     https://www.amazon.com.tr/Lenovo-Bilgisayar-i5...  15.499 TL
# 1     https://www.amazon.com.tr/ASUS-Vivobook-15-X15...  14.999 TL
# 2     https://www.amazon.com.tr/Lenovo-IdeaPad-Bilgi...  11.659 TL
# ...

# %%
new_df = new_df.sample(frac=1).reset_index(drop=True)
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1294 entries, 0 to 1293
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Image         1294 non-null   object
#  1   Link          1294 non-null   object
#  2   Price         1290 non-null   object
#  3   Product Name  1294 non-null   object
#  4   Reviews       1195 non-null   object
# dtypes: object(5)
# memory usage: 50.7+ KB

# %%
new_df
# Out:
#                                                   Image  \
# 0     https://n11scdn.akamaized.net/a1/226_339/10/26...
# 1     https://m.media-amazon.com/images/I/51FErozFOZ...
# 2     https://productimages.hepsiburada.net/s/191/42...
# 3     https://m.media-amazon.com/images/I/41cYWFzwVe...
# 4     https://n11scdn.akamaized.net/a1/226_339/01/63...
# ...                                                 ...
# 1289  https://n11scdn.akamaized.net/a1/226_339/04/36...
# 1290  https://productimages.hepsiburada.net/s/777/42...
# 1291  https://productimages.hepsiburada.net/s/447/42...
# 1292  https://cdn.dsmcdn.com/ty127/product/media/ima...
# 1293  https://n11scdn.akamaized.net/a1/226_339/09/81...
#
#                                                    Link      Price  \
# 0     https://www.n11.com/urun/onda-oliver-book-a1-n...   4.999 TL
# 1     https://www.amazon.com.tr/Notebook-Laptop-F150...  13.649 TL
# 2     https://www.hepsiburada.com/asus-x515ja-ej2676...  59.249 TL
# ...

# %%
new_df = new_df.dropna(subset=['Price'])
new_df.isna().sum()
# Out:
# Image            0
# Link             0
# Price            0
# Product Name     0
# Reviews         99
# dtype: int64

# %%
new_df = new_df.dropna(subset=['Reviews'])
new_df.isna().sum()
# Out:
# Image           0
# Link            0
# Price           0
# Product Name    0
# Reviews         0
# dtype: int64

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1191 entries, 0 to 1293
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Image         1191 non-null   object
#  1   Link          1191 non-null   object
#  2   Price         1191 non-null   object
#  3   Product Name  1191 non-null   object
#  4   Reviews       1191 non-null   object
# dtypes: object(5)
# memory usage: 55.8+ KB

# %%
new_df["Reviews"]
# Out:
# 0       31.01.2025 | Rating: 100 | Comment: Boyutuna g...
# 1       Gayet iyi bir laptop.İndirimdeyken aldım öğren...
# 2       Çok güzel ürün. Teşekkürler.; kaliteli ürün an...
# 3       daha öncede aldım memnun kaldık günlük kullanı...
# 4       07.01.2025 | Rating: 20 | Comment: ÜRÜN GELDİĞ...
#                               ...
# 1289    27.11.2024 | Rating: 100 | Comment: güzel pake...
# 1290    Ürünü 2 gündür kullanıyorum. Kutu içeriği olar...
# 1291    Ürün elimize hızlı bir şekilde ulaştı oldukça ...
# 1292    kardeşime aldim memnun || iki yıldır kullanıyo...
# 1293    10.01.2025 | Rating: 100 | Comment: 2 günde el...
# Name: Reviews, Length: 1191, dtype: object

# %%
new_df["Image"]
# Out:
# 0       https://n11scdn.akamaized.net/a1/226_339/10/26...
# 1       https://m.media-amazon.com/images/I/51FErozFOZ...
# 2       https://productimages.hepsiburada.net/s/191/42...
# 3       https://m.media-amazon.com/images/I/41cYWFzwVe...
# 4       https://n11scdn.akamaized.net/a1/226_339/01/63...
#                               ...
# 1289    https://n11scdn.akamaized.net/a1/226_339/04/36...
# 1290    https://productimages.hepsiburada.net/s/777/42...
# 1291    https://productimages.hepsiburada.net/s/447/42...
# 1292    https://cdn.dsmcdn.com/ty127/product/media/ima...
# 1293    https://n11scdn.akamaized.net/a1/226_339/09/81...
# Name: Image, Length: 1191, dtype: object

# %%
new_df["Price"]
# Out:
# 0        4.999 TL
# 1       13.649 TL
# 2       59.249 TL
# 3       15.499 TL
# 4       25.999 TL
#           ...
# 1289    26.799 TL
# 1290    55.799 TL
# 1291    16.905 TL
# 1292    13.999 TL
# 1293    36.499 TL
# Name: Price, Length: 1191, dtype: object

# %%
new_df["Link"]
# Out:
# 0       https://www.n11.com/urun/onda-oliver-book-a1-n...
# 1       https://www.amazon.com.tr/Notebook-Laptop-F150...
# 2       https://www.hepsiburada.com/asus-x515ja-ej2676...
# 3       https://www.amazon.com.tr/Dell-Vostro-i5-1235U...
# 4       https://www.n11.com/urun/huawei-matebook-d16-2...
#                               ...
# 1289    https://www.n11.com/urun/asus-tuf-gaming-f15-f...
# 1290    https://www.hepsiburada.com/monster-tulpar-t7-...
# 1291    https://www.hepsiburada.com/lenovo-ideapad-amd...
# 1292    https://www.trendyol.com/lenovo/ideapad-3-81w1...
# 1293    https://www.n11.com/urun/dell-g15-5530-g553024...
# Name: Link, Length: 1191, dtype: object

# %%
new_df.to_csv("cleaned_products.csv", index=False)
